# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %%
! ls

# %%
# %cd gdrive/My Drive/pav_spkid_pytorch
# Out:
# /content/gdrive/My Drive/pav_spkid_pytorch

# %%
! git clone https://github.com/pauri32/pav_spkid_pytorch.git

# %%
! git pull

# %%
! ls
# Out:
# 'Archivo comprimido'	   lpcc.zip	     spk_classification.log
# 'Archivo comprimido (1)'   make_spk2idx.py   test.py
# 'Archivo comprimido.zip'   mfcc		     train.py
#  cfg			   __pycache__	     Untitled0.ipynb
#  ckpt			   randomtest.py     utils.py
#  LICENSE		   README.md	     utils.pyc
#  lpcc			   results.txt

# %%
! python train.py --db_path lpcc/lpcc/lpcc
# Out:
# TRAINING: 680/1576 (Epoch 8) loss: 3.1310 acc:0.22 mean_btime: 0.016 s
# TRAINING: 700/1576 (Epoch 8) loss: 3.0568 acc:0.25 mean_btime: 0.016 s
# TRAINING: 720/1576 (Epoch 8) loss: 3.1210 acc:0.25 mean_btime: 0.016 s
# TRAINING: 740/1576 (Epoch 8) loss: 3.1319 acc:0.21 mean_btime: 0.016 s
# TRAINING: 760/1576 (Epoch 8) loss: 3.0733 acc:0.25 mean_btime: 0.016 s
# TRAINING: 780/1576 (Epoch 8) loss: 3.0703 acc:0.24 mean_btime: 0.016 s
# TRAINING: 800/1576 (Epoch 8) loss: 3.0408 acc:0.26 mean_btime: 0.016 s
# TRAINING: 820/1576 (Epoch 8) loss: 3.1406 acc:0.22 mean_btime: 0.016 s
# TRAINING: 840/1576 (Epoch 8) loss: 2.9998 acc:0.26 mean_btime: 0.016 s
# TRAINING: 860/1576 (Epoch 8) loss: 3.0602 acc:0.23 mean_btime: 0.016 s
# TRAINING: 880/1576 (Epoch 8) loss: 2.9982 acc:0.27 mean_btime: 0.016 s
# TRAINING: 900/1576 (Epoch 8) loss: 3.0311 acc:0.26 mean_btime: 0.016 s
# TRAINING: 920/1576 (Epoch 8) loss: 3.0290 acc:0.23 mean_btime: 0.016 s
# ...

# %%
! ls
# Out:
# 'Archivo comprimido'	        __pycache__
# 'Archivo comprimido (1)'        randomtest.py
# 'Archivo comprimido.zip'        README.md
#  cfg			        results1.txt
#  ckpt			        results.txt
#  LICENSE		        spk_classification.log
#  lpcc			        test.py
#  make_spk2idx.py	        train.py
#  mfcc			        utils.py
#  model_h2		        utils.pyc
#  pav_speaker_identifier.ipynb

# %%
! python test.py --weights_ckpt ckpt/e19_weights.ckpt --train_cfg ckpt/train.opts --log_file results1.txt --db_path lpcc/lpcc/lpcc --te_list_file cfg/all.test
# Out:
# python3: can't open file 'test.py': [Errno 2] No such file or directory

# %%
# !python train.py --save_path model_h2 --hsize 2 --in_frames=1 --db_path lpcc/lpcc/lpcc --tr_list_file cfg/all.train --va_list_file cfg/all.test
# Out:
# Parsed options:
# {
#   "db_path": "lpcc/lpcc/lpcc",
#   "tr_list_file": "cfg/all.train",
#   "va_list_file": "cfg/all.test",
#   "ext": "lpcc",
#   "spk2idx": "cfg/spk2idx.json",
#   "batch_size": 1000,
#   "hsize": 2,
#   "in_frames": 1,
#   "patience": 10,
#   "lr": 0.001,
#   "momentum": 0.5,
#   "epoch": 20,
#   "log_freq": 20,
#   "save_path": "model_h2"
# }
# ------------------------------
# 1/2355 Loading lpcc file lpcc/lpcc/lpcc/BLOCK00/SES000/SA000S01.lpcc
# 2/2355 Loading lpcc file lpcc/lpcc/lpcc/BLOCK00/SES000/SA000S02.lpcc
# 3/2355 Loading lpcc file lpcc/lpcc/lpcc/BLOCK00/SES000/SA000S05.lpcc
# 4/2355 Loading lpcc file lpcc/lpcc/lpcc/BLOCK00/SES000/SA000S06.lpcc
# 5/2355 Loading lpcc file lpcc/lpcc/lpcc/BLOCK00/SES000/SA000S07.lpcc
# 6/2355 Loading lpcc file lpcc/lpcc/lpcc/BLOCK00/SES000/SA000S08.lpcc
# 7/2355 Loading lpcc file lpcc/lpcc/lpcc/BLOCK00/SES000/SA000S10.lpcc
# 8/2355 Loading lpcc file lpcc/lpcc/lpcc/BLOCK00/SES000/SA000S15.lpcc
# ...

# %%
! python test.py --weights_ckpt model_lr0001/bestval_e19_weights.ckpt --train_cfg model_lr0001/train.opts --log_file resultslr0001.txt --db_path lpcc/lpcc/lpcc --te_list_file cfg/all.test
# Out:
# Created model:
# Sequential(
#   (0): Linear(in_features=13, out_features=100, bias=True)
#   (1): ReLU()
#   (2): Linear(in_features=100, out_features=100, bias=True)
#   (3): ReLU()
#   (4): Linear(in_features=100, out_features=100, bias=True)
#   (5): ReLU()
#   (6): Linear(in_features=100, out_features=158, bias=True)
#   (7): LogSoftmax()
# )
# -
# Loaded weights
# BLOCK00/SES000/SA000S13	SES069
# BLOCK00/SES000/SA000S14	SES000
# BLOCK00/SES000/SA000S22	SES069
# BLOCK00/SES000/SA000S24	SES069
# BLOCK00/SES000/SA000S28	SES069
# BLOCK00/SES001/SA001S14	SES001
# BLOCK00/SES001/SA001S15	SES080
# BLOCK00/SES001/SA001S24	SES080
# BLOCK00/SES001/SA001S27	SES205
# BLOCK00/SES001/SA001S29	SES205
# BLOCK00/SES002/SA002S12	SES206
# BLOCK00/SES002/SA002S13	SES069
# BLOCK00/SES002/SA002S23	SES069
# BLOCK00/SES002/SA002S26	SES206
# BLOCK00/SES002/SA002S28	SES206
# BLOCK00/SES003/SA003S11	SES003
# BLOCK00/SES003/SA003S15	SES003
# BLOCK00/SES003/SA003S22	SES003
# BLOCK00/SES003/SA003S25	SES003
# ...

# %%
# !python class_score.py results1.txt
# Out:
# 98.344

# %%
! python make_spk2idx.py
# Out:
# Num of spk available:  159
# Written spk2idx dict in cfg/spk2idx.json
